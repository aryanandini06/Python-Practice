# %% [markdown]
# ## Exceptions handing

# %%
try:
  a=b
except:
  print("the variables not be assigned")
# Out:
# the variables not be assigned

# %%
## we can write the error name directly , if  we know the name ..
# 1]
try:
  a=b
except NameError as ex:
  print(ex)
# Out:
# name 'b' is not defined

# %%
# 2]

try:
  result = 1/0
except ZeroDivisionError as zde:
  print(zde)
# Out:
# division by zero

# %%
# 3]
try:
  result= 3/2
  a=b

except ZeroDivisionError as zbe:
  print(zbe) 
  print(" please enter the denominator greater than 0")

except Exception as ex1:    ## excetion is use for all
  print(ex1)
# Out:
# name 'b' is not defined

# %%
###try, except, else..

try:


  num = int(input("enter a number:"))
  result = 10/num

except ValueError:
  print("that's  not a valid number")

except ZeroDivisionError:
  print(" you can not divide by 0!")
else:
  print(f"the result is {result}")
# Out:
#  you can not divide by 0!

# %%
###try, except, else, finally

try:


  num = int(input("enter a number:"))
  result = 10/num

except ValueError:
  print("that's  not a valid number")

except ZeroDivisionError:
  print(" you can not divide by 0!")
else:
  print(f"the result is {result}")
finally:
  print("execution complete")
# Out:
# the result is 0.43478260869565216
# execution complete

# %% [markdown]
# ## File handing and  Exception Handing

# %%
try:
  file = open('example.txt', 'r') 
  content= file.read()
  print(content)
except FileNotFoundError:
  print("the file not exits")
finally:
  if 'file' in locals() and not file.closed():
    file.close()
    print(file.close)
# Out:
# the file not exits
