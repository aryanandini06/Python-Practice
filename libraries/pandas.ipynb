# %% [markdown]
# # pandas

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.0 MB 3.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.0 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.0 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.0 MB 3.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/11.0 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.0 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 4.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
## a pandas Series is a one dimensional array-like object thta can hold any data type . it is similar to

import pandas as pd 
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n", series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# create a Series from dictionary
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
