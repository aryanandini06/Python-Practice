# %% [markdown]
# module

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi      # function in math    # math is the package
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np   # numpy is use when ever we want use arry, operation using aarry
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *     # * we able to excute all the function in math
print(sqrt(13))
print(pi)
# Out:
# 3.605551275463989
# 3.141592653589793

# %%
from packages.maths import addition
addition(12,4)
# Out:
# 16
